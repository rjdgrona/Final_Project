# %%
# importing required libraries
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv('data/FinalDataset.csv', parse_dates=["DateTime"])
station = df[df['Station']=='EMBR'].reset_index(drop=True)
station.head()
# Out:
#   Station            DateTime  Destination  Origin  Year     Day  Hour  \
# 0    EMBR 2016-01-01 00:00:00        301.0   821.0  2016  Friday     0
# 1    EMBR 2016-01-01 01:00:00        140.0  4590.0  2016  Friday     1
# 2    EMBR 2016-01-01 02:00:00        113.0  1958.0  2016  Friday     2
# 3    EMBR 2016-01-01 03:00:00         16.0   874.0  2016  Friday     3
# 4    EMBR 2016-01-01 04:00:00          1.0    28.0  2016  Friday     4
#
#     Latitude  Longitude
# 0 -122.39702  37.792874
# 1 -122.39702  37.792874
# 2 -122.39702  37.792874
# 3 -122.39702  37.792874
# 4 -122.39702  37.792874

# %%
station_plot = station[['DateTime','Origin']].set_index('DateTime')
plt.figure(figsize=(15,6))
plt.plot(station_plot)
plt.title("Per Station passenger trend (Jan 2016 ~ May 2017)")
plt.savefig('images/daily_EMBR.png')
plt.show()

# %%
#creating dataframe
new_data = pd.DataFrame(index=range(0,len(df)),columns=['Date', 'Origin'])

for i in range(0,len(station)):
    new_data['Date'][i] = station['DateTime'][i]
    new_data['Origin'][i] = station['Origin'][i]
    
new_data.head()
# Out:
#                   Date Origin
# 0  2016-01-01 00:00:00    821
# 1  2016-01-01 01:00:00   4590
# 2  2016-01-01 02:00:00   1958
# 3  2016-01-01 03:00:00    874
# 4  2016-01-01 04:00:00     28

# %%
#setting index
new_data.index = new_data.Date
new_data.drop('Date', axis=1, inplace=True)
new_data.head()
# Out:
#                     Origin
# Date
# 2016-01-01 00:00:00    821
# 2016-01-01 01:00:00   4590
# 2016-01-01 02:00:00   1958
# 2016-01-01 03:00:00    874
# 2016-01-01 04:00:00     28

# %%
new_data = new_data["2017"]
print(new_data.head())
new_data.size
# Out:
#                     Origin
# Date
# 2017-01-01 00:00:00    725
# 2017-01-01 01:00:00   5214
# 2017-01-01 02:00:00   2211
# 2017-01-01 03:00:00    627
# 2017-01-01 04:00:00     60
# 2632

# %%
#creating train and test sets
dataset = new_data.values

print(dataset.size)

train = dataset[0:2000,:]
valid = dataset[2000:,:]

print(train.size)
print(valid.size)
# Out:
# 2632
# 2000
# 632

# %%
#converting dataset into x_train and y_train
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

x_train, y_train = [], []
for i in range(60,len(train)):
    x_train.append(scaled_data[i-60:i,0])
    y_train.append(scaled_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))
# Out:
# C:\Users\jqkim\Anaconda\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
# create and fit the LSTM network
model = Sequential()

model.add(LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(Dropout(0.2))

model.add(LSTM(units=50))
model.add(Dropout(0.2))

model.add(Dense(1))

model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model.fit(x_train, y_train, epochs=100, batch_size=60)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0731 13:32:16.686628 18180 deprecation_wrapper.py:119] From C:\Users\jqkim\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0731 13:32:16.708644 18180 deprecation_wrapper.py:119] From C:\Users\jqkim\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0731 13:32:16.714649 18180 deprecation_wrapper.py:119] From C:\Users\jqkim\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0731 13:32:16.994885 18180 deprecation_wrapper.py:119] From C:\Users\jqkim\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0731 13:32:17.004912 18180 deprecation.py:506] From C:\Users\jqkim\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0731 13:32:17.227080 18180 deprecation_wrapper.py:119] From C:\Users\jqkim\Anaconda\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0731 13:32:17.494427 18180 deprecation.py:323] From C:\Users\jqkim\Anaconda\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0731 13:32:18.541832 18180 deprecation_wrapper.py:119] From C:\Users\jqkim\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Epoch 1/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0479
# Epoch 2/100
# 1940/1940 [==============================] - 3s 1ms/step - loss: 0.0357A: 0s - loss: 0.03
# Epoch 3/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0289
# Epoch 4/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0245
# Epoch 5/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0213
# Epoch 6/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0176
# Epoch 7/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0145
# Epoch 8/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0127
# Epoch 9/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0112
# Epoch 10/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0098
# Epoch 11/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0091A: 0s - loss: 0.0
# Epoch 12/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0084
# Epoch 13/100
# 1940/1940 [==============================] - 5s 3ms/step - loss: 0.0076
# Epoch 14/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0067
# Epoch 15/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0064
# Epoch 16/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0065
# Epoch 17/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0060
# Epoch 18/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0055
# Epoch 19/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0049
# Epoch 20/100
# 1940/1940 [==============================] - 3s 1ms/step - loss: 0.0046
# Epoch 21/100
# 1940/1940 [==============================] - 3s 1ms/step - loss: 0.0043
# Epoch 22/100
# 1940/1940 [==============================] - 3s 1ms/step - loss: 0.0042
# Epoch 23/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0041
# Epoch 24/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0040A: 0s - loss: 0.00
# Epoch 25/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0038
# Epoch 26/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0037
# Epoch 27/100
# 1940/1940 [==============================] - ETA: 0s - loss: 0.003 - 4s 2ms/step - loss: 0.0035
# Epoch 28/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0035
# Epoch 29/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0035
# Epoch 30/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0033
# Epoch 31/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0038
# Epoch 32/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0033
# Epoch 33/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0030
# Epoch 34/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0030
# Epoch 35/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0030
# Epoch 36/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0028
# Epoch 37/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0031
# Epoch 38/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0029
# Epoch 39/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0029
# Epoch 40/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0031A: 1s
# Epoch 41/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0027
# Epoch 42/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0028
# Epoch 43/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0026
# Epoch 44/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0026
# Epoch 45/100
# 1940/1940 [==============================] - 5s 2ms/step - loss: 0.0025
# Epoch 46/100
# 1940/1940 [==============================] - 5s 2ms/step - loss: 0.0026
# Epoch 47/100
# 1940/1940 [==============================] - 6s 3ms/step - loss: 0.0026
# Epoch 48/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0024
# Epoch 49/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0022
# Epoch 50/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0023
# Epoch 51/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0022
# Epoch 52/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0022
# Epoch 53/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0022
# Epoch 54/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0022
# Epoch 55/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0021
# Epoch 56/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0023
# Epoch 57/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0021
# Epoch 58/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0023
# Epoch 59/100
# 1940/1940 [==============================] - 5s 2ms/step - loss: 0.0022
# Epoch 60/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0023
# Epoch 61/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0018
# Epoch 62/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0021
# Epoch 63/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0022
# Epoch 64/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0019
# Epoch 65/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0021
# Epoch 66/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0019
# Epoch 67/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0019
# Epoch 68/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0021
# Epoch 69/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0020
# Epoch 70/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0021
# Epoch 71/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0020
# Epoch 72/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0019
# Epoch 73/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0021
# Epoch 74/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0019
# Epoch 75/100
# 1940/1940 [==============================] - 5s 3ms/step - loss: 0.0019
# Epoch 76/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0018
# Epoch 77/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0017
# Epoch 78/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0016
# Epoch 79/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0017
# Epoch 80/100
# 1940/1940 [==============================] - 5s 2ms/step - loss: 0.0020
# Epoch 81/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0019
# Epoch 82/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0018
# Epoch 83/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0017
# Epoch 84/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0018
# Epoch 85/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0019
# Epoch 86/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0019
# Epoch 87/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0016
# Epoch 88/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0017
# Epoch 89/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0017
# Epoch 90/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0018
# Epoch 91/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0016
# Epoch 92/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0017
# Epoch 93/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0017
# Epoch 94/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0017
# Epoch 95/100
# 1940/1940 [==============================] - 5s 2ms/step - loss: 0.0017
# Epoch 96/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0017
# Epoch 97/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0017
# Epoch 98/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0015
# Epoch 99/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0017
# Epoch 100/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0017

# %%
#predicting future values, using past 60 from the train data
inputs = new_data[len(new_data) - len(valid) - 60:].values
inputs = inputs.reshape(-1,1)
inputs  = scaler.transform(inputs)

X_test = []
for i in range(60,inputs.shape[0]):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)

X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
riders = model.predict(X_test)
riders = scaler.inverse_transform(riders)

# %%
rms=np.sqrt(np.mean(np.power((valid-riders),2)))
rms
# Out:
# 493.344469996129

# %%
#for plotting the results overall

train = new_data[:2000]
valid = new_data[2000:]
plt.figure(figsize=(15,6))
valid['Predictions'] = riders
plt.plot(train['Origin'], color='blue', label='Train EMBR', alpha=.5)
plt.plot(valid['Origin'], color='orange', label='Test EMBR')
plt.plot(valid['Predictions'], color='green', label='Predictions EMBR',alpha=.5)
plt.title('Train and Test EMBR BART data in 2017')
plt.xlabel('Date')
plt.ylabel('# of riders')
plt.legend()
plt.savefig("images/train_test_prediction_embr.png")
# Out:
# C:\Users\jqkim\Anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#for plotting the results
train = new_data[:2000]
valid = new_data[2000:]
plt.figure(figsize=(15,6))
valid['Predictions'] = riders
plt.plot(valid['Origin'], color='orange', label='Test EMBR')
plt.plot(valid['Predictions'], color='green', label='Predictions EMBR', alpha=.8)
plt.title('EMBR BART Prediction compared to Test')
plt.xlabel('Date')
plt.ylabel('# of riders')
plt.legend()
plt.savefig("images/test_prediction_embr.png")
# Out:
# C:\Users\jqkim\Anaconda\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
