# %%
# importing required libraries
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv('data/FinalDataset.csv', parse_dates=["DateTime"])
station = df[df['Station']=='SFIA'].reset_index(drop=True)
station.head()
# Out:
#   Station            DateTime  Destination  Origin  Year     Day  Hour  \
# 0    SFIA 2016-01-01 00:00:00          8.0   139.0  2016  Friday     0
# 1    SFIA 2016-01-01 01:00:00        113.0    64.0  2016  Friday     1
# 2    SFIA 2016-01-01 02:00:00         49.0    19.0  2016  Friday     2
# 3    SFIA 2016-01-01 03:00:00         30.0     5.0  2016  Friday     3
# 4    SFIA 2016-01-01 04:00:00          3.0     1.0  2016  Friday     4
#
#      Latitude  Longitude
# 0 -122.392409  37.615966
# 1 -122.392409  37.615966
# 2 -122.392409  37.615966
# 3 -122.392409  37.615966
# 4 -122.392409  37.615966

# %%
station_plot = station[['DateTime','Origin']].set_index('DateTime')
plt.figure(figsize=(15,6))
plt.plot(station_plot)
plt.title("Per Station passenger trend (Jan 2016 ~ May 2017)")
plt.savefig('images/daily_SFO.png')
plt.show()

# %%
#creating dataframe
new_data = pd.DataFrame(index=range(0,len(df)),columns=['Date', 'Origin'])

for i in range(0,len(station)):
    new_data['Date'][i] = station['DateTime'][i]
    new_data['Origin'][i] = station['Origin'][i]
    
new_data.head()
# Out:
#                   Date Origin
# 0  2016-01-01 00:00:00    139
# 1  2016-01-01 01:00:00     64
# 2  2016-01-01 02:00:00     19
# 3  2016-01-01 03:00:00      5
# 4  2016-01-01 04:00:00      1

# %%
#setting index
new_data.index = new_data.Date
new_data.drop('Date', axis=1, inplace=True)
new_data.head()
# Out:
#                     Origin
# Date
# 2016-01-01 00:00:00    139
# 2016-01-01 01:00:00     64
# 2016-01-01 02:00:00     19
# 2016-01-01 03:00:00      5
# 2016-01-01 04:00:00      1

# %%
new_data = new_data["2017"]
print(new_data.head())
new_data.size
# Out:
#                     Origin
# Date
# 2017-01-01 00:00:00    117
# 2017-01-01 01:00:00     60
# 2017-01-01 02:00:00     25
# 2017-01-01 03:00:00      5
# 2017-01-01 04:00:00      0
# 2640

# %%
#creating train and test sets
dataset = new_data.values

print(dataset.size)

train = dataset[0:2000,:]
valid = dataset[2000:,:]

print(train.size)
print(valid.size)
# Out:
# 2640
# 2000
# 640

# %%
#converting dataset into x_train and y_train
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

x_train, y_train = [], []
for i in range(60,len(train)):
    x_train.append(scaled_data[i-60:i,0])
    y_train.append(scaled_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))
# Out:
# C:\Users\jqkim\Anaconda\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
# create and fit the LSTM network
model = Sequential()

model.add(LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(Dropout(0.2))

model.add(LSTM(units=50))
model.add(Dropout(0.2))

model.add(Dense(1))

model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model.fit(x_train, y_train, epochs=100, batch_size=60)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0731 13:38:51.583708 15496 deprecation_wrapper.py:119] From C:\Users\jqkim\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0731 13:38:51.611728 15496 deprecation_wrapper.py:119] From C:\Users\jqkim\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0731 13:38:51.616735 15496 deprecation_wrapper.py:119] From C:\Users\jqkim\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0731 13:38:51.986023 15496 deprecation_wrapper.py:119] From C:\Users\jqkim\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0731 13:38:51.996030 15496 deprecation.py:506] From C:\Users\jqkim\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0731 13:38:52.310299 15496 deprecation_wrapper.py:119] From C:\Users\jqkim\Anaconda\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0731 13:38:52.595561 15496 deprecation.py:323] From C:\Users\jqkim\Anaconda\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0731 13:38:53.724382 15496 deprecation_wrapper.py:119] From C:\Users\jqkim\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Epoch 1/100
# 1940/1940 [==============================] - 5s 2ms/step - loss: 0.0182
# Epoch 2/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0115
# Epoch 3/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0081
# Epoch 4/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0044
# Epoch 5/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0040
# Epoch 6/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0036
# Epoch 7/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0035
# Epoch 8/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0035
# Epoch 9/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0036
# Epoch 10/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0033
# Epoch 11/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0034
# Epoch 12/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0034
# Epoch 13/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0033
# Epoch 14/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0031
# Epoch 15/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0032
# Epoch 16/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0029
# Epoch 17/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0031
# Epoch 18/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0029
# Epoch 19/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0029
# Epoch 20/100
# 1940/1940 [==============================] - 3s 1ms/step - loss: 0.0030
# Epoch 21/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0030
# Epoch 22/100
# 1940/1940 [==============================] - 3s 1ms/step - loss: 0.0027A: 2s - loss: 0.00 - E
# Epoch 23/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0027
# Epoch 24/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0027
# Epoch 25/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0026
# Epoch 26/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0026
# Epoch 27/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0026
# Epoch 28/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0026
# Epoch 29/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0027
# Epoch 30/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0025
# Epoch 31/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0025A: 0s - l
# Epoch 32/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0025
# Epoch 33/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0025
# Epoch 34/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0025
# Epoch 35/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0024A: 0s - lo
# Epoch 36/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0024
# Epoch 37/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0022
# Epoch 38/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0024
# Epoch 39/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0023
# Epoch 40/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0024
# Epoch 41/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0023
# Epoch 42/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0022
# Epoch 43/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0021
# Epoch 44/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0022
# Epoch 45/100
# 1940/1940 [==============================] - 3s 1ms/step - loss: 0.0022
# Epoch 46/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0021
# Epoch 47/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0021
# Epoch 48/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0023
# Epoch 49/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0022
# Epoch 50/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0021A
# Epoch 51/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0023
# Epoch 52/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0022
# Epoch 53/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0022
# Epoch 54/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0021
# Epoch 55/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0021
# Epoch 56/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0023
# Epoch 57/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0021
# Epoch 58/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0020
# Epoch 59/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0022
# Epoch 60/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0021
# Epoch 61/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0019
# Epoch 62/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0020A: 0s - los
# Epoch 63/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0020
# Epoch 64/100
# 1940/1940 [==============================] - 3s 1ms/step - loss: 0.0021
# Epoch 65/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0020
# Epoch 66/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0021
# Epoch 67/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0019
# Epoch 68/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0019A: 0s - los
# Epoch 69/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0019
# Epoch 70/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0020
# Epoch 71/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0020
# Epoch 72/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0019
# Epoch 73/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0019
# Epoch 74/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0020
# Epoch 75/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0020
# Epoch 76/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0020
# Epoch 77/100
# 1940/1940 [==============================] - 5s 2ms/step - loss: 0.0020
# Epoch 78/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0020
# Epoch 79/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0020
# Epoch 80/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0020
# Epoch 81/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0019
# Epoch 82/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0019
# Epoch 83/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0021
# Epoch 84/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0020
# Epoch 85/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0019
# Epoch 86/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0019
# Epoch 87/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0020
# Epoch 88/100
# 1940/1940 [==============================] - 5s 2ms/step - loss: 0.0019
# Epoch 89/100
# 1940/1940 [==============================] - 5s 3ms/step - loss: 0.0019
# Epoch 90/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0019
# Epoch 91/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0019
# Epoch 92/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0019A: 0s - loss:
# Epoch 93/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0018
# Epoch 94/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0019
# Epoch 95/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0019A: 1s  - ETA: 0s - loss:
# Epoch 96/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0019
# Epoch 97/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0019
# Epoch 98/100
# 1940/1940 [==============================] - 4s 2ms/step - loss: 0.0019
# Epoch 99/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0018
# Epoch 100/100
# 1940/1940 [==============================] - 3s 2ms/step - loss: 0.0018

# %%
#predicting future values, using past 60 from the train data
inputs = new_data[len(new_data) - len(valid) - 60:].values
inputs = inputs.reshape(-1,1)
inputs  = scaler.transform(inputs)

X_test = []
for i in range(60,inputs.shape[0]):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)

X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
riders = model.predict(X_test)
riders = scaler.inverse_transform(riders)

# %%
rms=np.sqrt(np.mean(np.power((valid-riders),2)))
rms
# Out:
# 63.20233893978271

# %%
#for plotting the results overall

train = new_data[:2000]
valid = new_data[2000:]
plt.figure(figsize=(15,6))
valid['Predictions'] = riders
plt.plot(train['Origin'], color='blue', label='Train SFO', alpha=.5)
plt.plot(valid['Origin'], color='orange', label='Test SFO')
plt.plot(valid['Predictions'], color='green', label='Predictions SFO',alpha=.5)
plt.title('Train and Test SFO BART data in 2017')
plt.xlabel('Date')
plt.ylabel('# of riders')
plt.legend()
plt.savefig("images/train_test_prediction_sfia.png", dpi=150)
# Out:
# C:\Users\jqkim\Anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#for plotting the results
train = new_data[:2000]
valid = new_data[2000:]
plt.figure(figsize=(15,6))
valid['Predictions'] = riders
plt.plot(valid['Origin'], color='orange', label='Test SFO')
plt.plot(valid['Predictions'], color='green', label='Predictions SFO', alpha=.8)
plt.title('SFO BART Prediction compared to Test')
plt.xlabel('Date')
plt.ylabel('# of riders')
plt.legend()
plt.savefig("images/test_prediction_sfia.png", dpi=150)
# Out:
# C:\Users\jqkim\Anaconda\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
